# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAhtishamYousaf/LeetCode-Solutions/blob/main/LeetCode_Solution03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Given two strings `needle` and `haystack`, return the index of the first occurrence of needle in haystack, or `-1` if needle is not part of haystack.

# %%
needle = 'leeto'
haystack = 'leetcode'

if needle in haystack:
    print(haystack.index(needle))
else:
    print(-1)
# Out:
# -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
